# %%
from IPython.display import HTML
import warnings
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import seaborn as sns

# %%
HTML('''
<script>
  function code_toggle() {
    if (code_shown){
      $('div.input').hide('500');
      $('#toggleButton').val('Show Code')
    } else {
      $('div.input').show('500');
      $('#toggleButton').val('Hide Code')
    }
    code_shown = !code_shown
  }

  $( document ).ready(function(){
    code_shown=false;
    $('div.input').hide()
  });
</script>
<form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>''')
# Out:
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %%
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("C:\\Users\\hp\\Desktop\\AI\\***\\Analytics Academy\\sender_data.csv")
#print(ds)
df.head()
# Out:
#    Unnamed: 0  message_id  user_id_sender        date time_sent message_type  \
# 0           1      147420     14850129222  2017-12-24  11:09:43         text
# 1           2      123567    149847316413  2017-12-24  05:25:05         text
# 2           3      103163     15008022084  2017-12-24  00:35:43         text
# 3           4      144538    155489657603  2017-12-24  10:28:58         text
# 4           5      107753    161201232269  2017-12-24  01:40:49        photo
#
#     sender_carrier sender_device_type sender_device_os sender_device_make
# 0  O2 / Telefonica             mobile          Android                HTC
# 1             AT&T             mobile          Android                 LG
# 2  O2 / Telefonica             tablet              iOS               iPad
# 3         Vodafone             mobile          Android             Huawei
# 4  O2 / Telefonica             mobile          Android            Samsung

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df.head()
# Out:
#    message_id  user_id_sender        date time_sent message_type  \
# 0      147420     14850129222  2017-12-24  11:09:43         text
# 1      123567    149847316413  2017-12-24  05:25:05         text
# 2      103163     15008022084  2017-12-24  00:35:43         text
# 3      144538    155489657603  2017-12-24  10:28:58         text
# 4      107753    161201232269  2017-12-24  01:40:49        photo
#
#     sender_carrier sender_device_type sender_device_os sender_device_make
# 0  O2 / Telefonica             mobile          Android                HTC
# 1             AT&T             mobile          Android                 LG
# 2  O2 / Telefonica             tablet              iOS               iPad
# 3         Vodafone             mobile          Android             Huawei
# 4  O2 / Telefonica             mobile          Android            Samsung

# %%
df.shape
# Out:
# (332781, 9)

# %%
sns.countplot(x = 'sender_device_os',data = df,hue = 'sender_device_os')

# %%
sns.countplot(x = 'sender_device_type',data = df,hue = 'sender_device_type')

# %%
sns.countplot(x = 'sender_carrier',data = df,hue = 'sender_carrier')

# %%
sns.countplot(x = 'message_type',data = df,hue = 'message_type')

# %%
plt.figure(figsize = (20,12))
sns.countplot(x = 'sender_device_make',data = df,hue = 'sender_device_make')

# %%
sns.countplot(x = 'date',data = df,hue = 'date')

# %%
corr=df.corr()
sns.heatmap(corr, xticklabels=corr.columns.values, yticklabels=corr.columns.values)

# %%
print(len(df.duplicated('user_id_sender', keep=False)))
print(len(df.duplicated('time_sent', keep=False)))
# Out:
# 332781
# 332781

# %%
# https://datatofish.com/count-duplicates-pandas/
duplicatesnumber = df.pivot_table(index=['user_id_sender'], aggfunc='size')
sortedlist = duplicatesnumber.sort_values(ascending = False) 
print(sortedlist)
# Out:
# user_id_sender
# 301582240016    106
# 19492391373     100
# 945876184863    100
# 836230774757    100
# 937262275848     97
# 386172527130     96
# 974397190688     96
# 264438537493     96
# 426340696186     96
# 495079708803     96
# 48438624602      95
# 672519459224     94
# 488418712613     94
# 556836178148     94
# 918253207417     94
# 327620839129     94
# 605659260351     94
# 706641622541     94
# 190236188015     93
# 237578846112     93
# 924498743959     93
# 6386687731       93
# 415164580079     93
# 273300371028     92
# 248440351256     92
# 15348747980      92
# 197314691387     92
# 755269169357     92
# 733256754026     92
# 262193243276     92
#                ...
# 97200716602      39
# 590679487310     39
# 92958238691      39
# 929290721596     39
# 228778819465     39
# 466354770670     39
# 35744250372      39
# 75031740990      39
# 35860845106      39
# 441633716175     39
# 953740117387     39
# 186050410774     38
# 992988404763     38
# 798232858189     38
# 862698974189     38
# 816212118316     38
# 567302694330     38
# 111436640926     37
# 326267920776     37
# 144360373020     37
# 941177932608     37
# 369201970689     37
# 107566529872     36
# 757627328087     36
# 559680747506     36
# 785004359691     35
# 960481245158     34
# 35570911359      32
# 371036200147     32
# 60746101688      28
# Length: 5000, dtype: int64

# %%
plt.figure(figsize = (12,8))
sns.distplot(sortedlist)
print("Mean number of messages an user sended throughout the considered period",np.mean(sortedlist))
# Out:
# Mean number of messages an user sended throughout the considered period 66.5562

# %%
r = np.array(sortedlist.index[0:20].values)
r2 = np.array(sortedlist[0:20])
d = {'user': r, 'number of messages': r2}
df2 = pd.DataFrame(data=d)
df2.head()
# Out:
#            user  number of messages
# 0  301582240016                 106
# 1   19492391373                 100
# 2  945876184863                 100
# 3  836230774757                 100
# 4  937262275848                  97

# %%
plt.figure(figsize = (15,12))
y_pos = np.arange(len(df2['user']))
sns.barplot(y =y_pos, x=df2['number of messages'], palette = 'rocket', orient = 'h')
plt.title("How many messages sent the top user_id_sender (Top 20)")
plt.yticks(y_pos, df2['user'])
plt.ylabel('User ID')
#plt.xticks(rotation = 90)
sns.despine(left=True, bottom=True)

# %%
duplicatesnumber = df.pivot_table(index=['time_sent'], aggfunc='size')
#print(duplicatesnumber)
sortedlist = duplicatesnumber.sort_values(ascending = False) 
print(sortedlist)
# Out:
# time_sent
# 08:57:30    15
# 12:09:17    14
# 22:24:33    14
# 23:26:47    14
# 07:42:52    13
# 08:27:37    13
# 21:28:54    13
# 09:42:33    13
# 05:24:47    13
# 14:04:28    13
# 04:27:46    13
# 03:53:02    13
# 15:21:14    13
# 01:15:49    13
# 08:42:27    13
# 16:37:17    13
# 02:03:49    13
# 13:03:33    13
# 05:07:11    13
# 04:46:43    13
# 10:29:37    13
# 11:48:11    13
# 13:56:34    12
# 12:04:28    12
# 16:14:02    12
# 12:04:05    12
# 18:38:09    12
# 23:49:50    12
# 12:29:10    12
# 12:07:00    12
#             ..
# 20:21:36     1
# 21:24:40     1
# 02:14:27     1
# 21:24:42     1
# 20:21:43     1
# 16:50:23     1
# 16:50:24     1
# 11:52:59     1
# 06:06:47     1
# 02:14:17     1
# 02:14:15     1
# 02:14:50     1
# 11:53:37     1
# 02:15:28     1
# 11:54:04     1
# 02:15:27     1
# 16:49:00     1
# 16:49:02     1
# 20:21:49     1
# 02:15:19     1
# 22:40:30     1
# 16:49:21     1
# 23:30:33     1
# 21:24:29     1
# 06:05:56     1
# 11:53:55     1
# 06:06:02     1
# 20:21:46     1
# 11:53:50     1
# 17:06:11     1
# Length: 84625, dtype: int64

# %%
r = np.array(sortedlist.index[0:20].values)
r2 = np.array(sortedlist[0:20])
d = {'user': r, 'number of messages': r2}
df2 = pd.DataFrame(data=d)
df2.head()
# Out:
#        user  number of messages
# 0  08:57:30                  15
# 1  12:09:17                  14
# 2  22:24:33                  14
# 3  23:26:47                  14
# 4  07:42:52                  13

# %%
plt.figure(figsize = (15,12))
y_pos = np.arange(len(df2['user']))
sns.barplot(y =y_pos, x=df2['number of messages'], palette = 'rocket', orient = 'h')
plt.title("Most common times users sends messages simulatneusly (Top 20)")
plt.yticks(y_pos, df2['user'])
plt.ylabel('Time')
#plt.xticks(rotation = 90)
sns.despine(left=True, bottom=True)

# %%
duplicatesnumber = df.pivot_table(index=['message_id'], aggfunc='size')
sortedlist = duplicatesnumber.sort_values(ascending = False) 
print("There are no duplicates in message_id, each message sent has his unique id")
print(sortedlist)
# Out:
# There are no duplicates in message_id, each message sent has his unique id
# message_id
# 500000    1
# 223358    1
# 223320    1
# 223322    1
# 223324    1
# 223327    1
# 223333    1
# 223335    1
# 223336    1
# 223338    1
# 223343    1
# 223344    1
# 223345    1
# 223346    1
# 223347    1
# 223348    1
# 223350    1
# 223352    1
# 223354    1
# 223319    1
# 223317    1
# 223315    1
# 223300    1
# 223283    1
# 223286    1
# 223287    1
# 223290    1
# 223293    1
# 223298    1
# 223299    1
#          ..
# 380704    1
# 380691    1
# 380705    1
# 380706    1
# 380707    1
# 380708    1
# 380709    1
# 380711    1
# 380712    1
# 380692    1
# 380690    1
# 380671    1
# 380679    1
# 380672    1
# 380673    1
# 380674    1
# 380675    1
# 380676    1
# 380677    1
# 380678    1
# 380680    1
# 380689    1
# 380681    1
# 380682    1
# 380683    1
# 380684    1
# 380686    1
# 380687    1
# 380688    1
# 100671    1
# Length: 332781, dtype: int64
